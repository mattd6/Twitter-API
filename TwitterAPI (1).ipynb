# %% [markdown]
# Imports, Twitter API Authentication

# %%
import tweepy,json
import os
import pandas as pd
import sys
import csv

#Enter names of API keys and tokens. These act as login credentials
access_token="<insert access token>"
access_token_secret="<insert secret access token>"
consumer_key="<insert consumer key>"
consumer_secret="<insert secret consumer key>"

auth= tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# Tell the program to search twitter for tweets containing the term(s) contained in search_words

# %%
search_words = "are -filter:retweets"

date_since = "2014-03-12"

# %% [markdown]
# Collect tweets. .Cursor() searches for tweets containing the search word. Specify how many tweets to return by typing number in .items()

# %%
tweets = tweepy.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(600)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# @Porkchop_EXP Are there any other kind of grasshoppers? Seems like it'd be weird to not hear them.
# @NgolaBlink @Rhadebelihle Something like that is so fitting. Because who knows, when all claims are plausible 🤣🤣🤣
# Funny because the person you are demonizing on the image (@martinplaut) wrote the article alleging TPLF used aid fo… https://t.co/VQq189KmSB
# @Dean80041859 @HiddenForcesPod In this poll one can see why humans are obliviously destroying the planet and how 74… https://t.co/sPrxoEbgXB
# @estanley6 @jfhksar88 If you don't think crypto will survive, then you are not doing a deep dive. Centralized datab… https://t.co/L5RAKmebFB
# @BlasterUncommon Some people are saying local supermarkets here are short of basic things like veg and milk, but it… https://t.co/LYPxwRqSaS
# @oliveira_alef21 @Ihadnoideaatall @brfootball Look mate each team is allowed to invite three 23+ players to their o… https://t.co/DjGvMjNcgn
# ...

# %% [markdown]
# Store user tweets and users in a list

# %%
tweets = tweepy.Cursor(api.search, 
                           q=search_words,
                           lang="en",
                           since=date_since).items(600)

users_locs = [[tweet.text, tweet.user.screen_name, tweet.user.id] for tweet in tweets]
users_locs
# Out:
# [["@xMaruu11 Oooooooo I love this, the colors are just mwah *chefs kiss* I'm so excited for the next part",
#   'Synthetichuman5',
#   965080806216650753],
#  ['@MySportsUpdate Vikings are awful at drafting',
#   'UncGotGame23',
#   876569848637255682],
#  ['@JackPosobiec Harassment and assault are a bit different, eh?',
#   'RYRUMMLER',
#   1204501406331392007],
#  ['@VegasMikeL @thebradfordfile Well     vaccinated people are spreading it’s there’s that',
#   'Joe22668238',
#   1407090890846441475],
#  ['@GOP It appears that @GOP @GOPChairwoman @GOPSenate @GOPHouse lack quite a bit of intelligence\n\nThe Borders are not open',
#   'rmtahmosh',
#   1410677991663878144],
#  ['@26hzm Bulls are gonna be tough this year',
#   'ri_prince1',
#   1038724148648988672],
#  ['@DeaconBlues0 And the people are willing to sacrifice their children to please desantis. In turn this pleases trump.',
#   'gierzak_irene',
#   952415351106498560],
# ...

# %% [markdown]
# Put list into dataset

# %%
df = pd.DataFrame(data=users_locs, 
                    columns=['text','user', "id"])
df
# Out:
#                                                   text  ...                   id
# 0    @xMaruu11 Oooooooo I love this, the colors are...  ...   965080806216650753
# 1        @MySportsUpdate Vikings are awful at drafting  ...   876569848637255682
# 2    @JackPosobiec Harassment and assault are a bit...  ...  1204501406331392007
# 3    @VegasMikeL @thebradfordfile Well     vaccinat...  ...  1407090890846441475
# 4    @GOP It appears that @GOP @GOPChairwoman @GOPS...  ...  1410677991663878144
# ..                                                 ...  ...                  ...
# 595  @Unitaria8 @StevenDelDuca @OntarioNDP You must...  ...  1187561357039800320
# 596  @mny_mrk @Breaking911 Landlords are wealthy? L...  ...           2961535509
# 597  TPLF’s and OFC’s Demand are Poison Pills to Re...  ...           2430741571
# 598  @Dangerdave1979 @winkybiker @gazzadaz There ar...  ...            721145094
# 599  why are my hips so narrow. if this was a centu...  ...  1342632608405065728
#
# ...

# %% [markdown]
# Save Dataset

# %%
from google.colab import drive
drive.mount('drive', force_remount=True)

df.to_csv('drive/My Drive/RandomHateTweets2.csv', index=None, header=True)
#pd.read_csv('hatetweets1.csv')
# Out:
# Mounted at drive
